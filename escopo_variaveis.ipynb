# %%
#VARIÁVEIS ESCOPO GLOBAL. FICAM FORA DAS FUNCTIONS
nome = "Maria do Carmo"
mensagem = "Olá"
print(nome)
# Out:
# Maria do Carmo

# %% [markdown]
# Variáveis locais. Dentro da function

# %%
def minha_function():
    nome= "Carmem"
    mensagem = "Olá"
    print(f"\nDentro da funtion:   {mensagem}  {nome}")

minha_function()
# Out:
# Dentro da funtion:   Olá  Carmem
